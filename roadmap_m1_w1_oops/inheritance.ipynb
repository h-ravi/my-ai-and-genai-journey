# %%
class Person:
    def __init__(self,name,mobile):
        self.namer = name
        self.mobile = mobile
    def Login(self):
        print("Login")

class Customer(Person):
    pass
class Employee(Person):
    pass
class Admin(Person)
