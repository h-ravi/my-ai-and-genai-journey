# %% [markdown]
# # Python Practice Questions
#
# Solve each question in the code cell below it.

# %% [markdown]
# 1. Create a variable `age` with your age and print its `type()`.

# %%
# Write your solution here
age = 25
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# 2. Take two numbers as input (convert both using `int()`), then print their sum.

# %%
# Write your solution here
num1 = int(input("Enter First Number : "))
num2 = int(input("Enter Second Number : "))
add = num1+num2
print("Sum of num1 and num 2 :", add)
# Out:
# Enter First Number : 20
# Enter Second Number : 30
# Sum of num1 and num 2 : 50

# %% [markdown]
# 3. Take the radius of a circle as input, calculate the area (`3.14159 * r * r`), and print it.

# %%
# Write your solution here
radius = int(input("Enter Value of circle radius : "))
pi = 3.14
circleArea = pi*radius*radius
print("Circle Area is :", circleArea)
# Out:
# Enter Value of circle radius : 10
# Circle Area is : 314.0

# %% [markdown]
# 4. Swap the values of two variables `a` and `b` **without using a third variable**.

# %%
# Write your solution here

a = 10
b = 20

print("brefore swaping")
print("Value of a :", a)
print("Value of b :", b)

a , b = b, a

print("After Swaping")
print("Value of a :", a)
print("Value of b :", b)
# Out:
# brefore swaping
# Value of a : 10
# Value of b : 20
# After Swaping
# Value of a : 20
# Value of b : 10

# %% [markdown]
# 5. Take Celsius as input and convert it to Fahrenheit using: `F = C * 9/5 + 32`.

# %%
# Write your solution here
celsius = int(input("Enter Value in celsius :"))
convert = celsius*9/5+32
print("value in Fahrenheit :", convert)
# Out:
# Enter Value in celsius :40
# value in Fahrenheit : 104.0

# %% [markdown]
# 6. Take `name` and `age` as input, then print using an f-string: `"My name is X and I am Y years old."`

# %%
# Write your solution here
name = input("Enter your name :")
age = int(input("Enter your age :"))
print(f"My name is {name} and I am {age} years old.")
# Out:
# Enter your name :Jay
# Enter your age :20
# My name is Jay and I am 20 years old.

# %% [markdown]
# 7. Take a number as input. First print its `type()` immediately after input, then convert it using `int()` and print its `type()` again.

# %%
# Write your solution here
inputN = input("Enter Your NUmber :")
print(f"you enter value is '{inputN}' and it's type {type(inputN)}")
intN = int(inputN)
print(f"after converting integer {intN} and it's type {type(intN)}")
# Out:
# Enter Your NUmber :100
# you enter value is '100' and it's type <class 'str'>
# after converting integer 100 and it's type <class 'int'>

# %% [markdown]
# 8. Create a Simple Interest calculator. Take `principal`, `rate`, and `time` as `float` inputs, then calculate `SI = (P * R * T) / 100` and print it.

# %%
# Write your solution here
p = float(input("Enter Principle Value :"))
r = float(input("Enter Rate :"))
t = float(input("Enter time :"))
SI = (p*r*t)/100
print(f"Simple Intrest is : {SI}")
# Out:
# Enter Principle Value :1000
# Enter Rate :10
# Enter time :1
# Simple Intrest is : 100.0

# %% [markdown]
# 9. Take two numbers and print the results of the `//`, `%`, and `**` operators.

# %%
# Write your solution here
a = 10
b = 3
c = a//b
d = a%b
e = a**b
print(c)
print(d)
print(e)
# Out:
# 3
# 1
# 1000

# %% [markdown]
# 10. Take `first_name` and `last_name` as separate inputs, join them with a space, and print `full_name`.

# %%
# Write your solution here
fName = input("Enter Your Name :")
lName = input("Enter your last name :")
print(f"Your FUll name is {fName} {lName}.")
# Out:
# Enter Your Name :Raj
# Enter your last name :kumar
# Your FUll name is Raj kumar.

# %% [markdown]
# 11. Print a string 5 times using the `*` operator (do not use a loop).

# %%
# Write your solution here
stre = "Hello"
print(stre*5)
# Out:
# HelloHelloHelloHelloHello

# %% [markdown]
# 12. Take two numbers and print the results of `==`, `!=`, `<`, and `>` operators. Observe which data type is returned.

# %%
# Write your solution here
a = 10
b = 20
c = a==b
d = a!=b
e = a>b
f = a<b
print(f"a equal to b or not : {c}, and Data type {type(c)}")
print(f"a not equal to b or not : {d}, and Data type {type(d)}")
print(f"a is grater then b or not : {e}, and Data type {type(e)}")
print(f"a is less then b or not : {f}, and Data type {type(f)}")
# Out:
# a equal to b or not : False, and Data type <class 'bool'>
# a not equal to b or not : True, and Data type <class 'bool'>
# a is grater then b or not : False, and Data type <class 'bool'>
# a is less then b or not : True, and Data type <class 'bool'>

# %% [markdown]
# 13. Take weight (kg) and height (meters) as input, then calculate BMI using: `BMI = weight / (height ** 2)`.

# %%
# Write your solution here
weight = float(input("Enter weight :"))
height = float(input("Enter Height :"))
BMI = weight/(height ** 2)
print(f"Your Bmi is {BMI}")
# Out:
# Enter weight :80
# Enter Height :1.5
# Your Bmi is 35.55555555555556

# %% [markdown]
# 14. Take total seconds as input (`int`), then convert and print it as hours, minutes, and seconds using `//` and `%`.

# %%
# Write your solution here
sec = int(input("Enter Second :"))
print(f"{sec//3600} houre {(sec%3600)//60} minute and {sec % 60} second")
# Out:
# Enter Second :3665
# 1 houre 1 minute and 5 second

# %% [markdown]
# 15. Take an item's price and discount percentage as input, calculate the final price, and print it.

# %%
# Write your solution here
totalPrice = 100
disper = int(input("Enter Discount in percentage :"))
discount = totalPrice*disper/100
finalPrice = totalPrice-discount
print(f"Total Price {totalPrice} rupee, Discount {discount}% and final price is {finalPrice} rupee")
# Out:
# Enter Discount in percentage :10
# Total Price 100 rupee, Discount 10.0% and final price is 90.0 rupee

# %% [markdown]
# 16. Predict the outputs of `bool(0)`, `bool(1)`, `bool("")`, `bool("hello")`, and `bool(None)`. Then write code to verify your predictions.

# %%
# Write your solution here

# my prediction is 
# bool(0) = False
# bool(1) = True
# bool("") = False
# bool("hello") = True

#check
print(f'bool(0) = {bool(0)}, bool(1) = {bool(1)}, bool("") = {bool("")}, bool("hello") = {bool("hello")}')
# Out:
# bool(0) = False, bool(1) = True, bool("") = False, bool("hello") = True

# %% [markdown]
# 17. Take two numbers, calculate their average, and print it using an f-string in the format: `"Average: X"`.

# %%
# Write your solution here
a = int(input("Enter first number :"))
b = int(input("Enter second number :"))
print(f'Average of {a} and {b} is {(a+b)/2}')
# Out:
# Enter first number :10
# Enter second number :40
# Average of 10 and 40 is 25.0

# %% [markdown]
# 18. Take an amount in Indian Rupees (`int`) as input, convert it to US Dollars (assume `1 USD = 83 INR`), and print the result up to 2 decimal places (you may use `round()`).

# %%
# Write your solution here
rupee = int(input("Enter total rupee :"))
usd = 83
con = rupee/usd
print(f'total rupee ({rupee}) in usd = {round(con, 2)}')
# Out:
# Enter total rupee :700
# total rupee (700) in usd = 8.43
