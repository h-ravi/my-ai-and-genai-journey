# %%
num = int(input("Enter a number: "))
print(100/num)
# Out:
# Enter a number: 0
#
# __ERROR__
# Traceback (most recent call last):
#   File "/home/h/Downloads/Dev/python_projects/pyide/ami/app.py", line 512, in execute_code_thread
#     exec(compile(code_stripped, '<string>', 'exec'), globals_dict, locals_dict)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
# ZeroDivisionError: division by zero

# %%
num = int(input("Enter a number: "))
print(100/num)
# Out:
# Enter a number: 10
# 10.0

# %%
# handle error
try:
    num = int(input("Enter a number: "))
    print(100/num)
except:
    print("please not give value in 0 or english latter")
# Out:
# Enter a number: 0
# please not give value in 0 or english latter

# %%
try:
    num = int(input("Enter a number: "))
    print(100/num)
except ValueError:
    print("please not give english latter")
except ZeroDivisionError:
    print("Please not give value in xero")
# Out:
# Enter a number: adasd
# please not give english latter

# %%
try:
    num = int(input("Enter a number: "))
    print(100/num)
except ValueError:
    print("please not give english latter")
except ZeroDivisionError:
    print("Please not give value in xero")
else:
    print(f'you enterd {num}')
# Out:
# Enter a number: 34
# 2.9411764705882355
# you enterd 34

# %%
try:
    num = int(input("Enter a number: "))
    print(100/num)
except ValueError:
    print("please not give english latter")
except ZeroDivisionError:
    print("Please not give value in xero")
else:
    print(f'you enterd {num}')
finally:
    print("Programin run compleated")
# Out:
# Enter a number: 20
# 5.0
# you enterd 20
# Programin run compleated
