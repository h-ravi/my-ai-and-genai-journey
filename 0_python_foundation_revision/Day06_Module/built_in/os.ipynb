# %%
import os

# %%
# current working directory
print(os.getcwd())
# Out:
# /home/h/Downloads/Dev/python_projects/AI_and_GenAI/my-ai-and-genai-journey/python_foundation_revision/Day06_Module

# %%
# current working directory me kaun kaun se files and folder hai (nested nahi)
print(os.listdir())
# Out:
# ['add.py', 'add2.py', '__pycache__', 'basic.ipynb', 'built_in']

# %%
# folder banana
os.mkdir('Demo')

# %%
os.cpu_count()
# Out:
# 2

# %%
print(os.path.exists('add3.py'))
# Out:
# False
