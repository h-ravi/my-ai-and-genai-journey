# %%
import datetime as d

# %%
print(d.datetime.now())
# Out:
# 2026-08-04 11:39:28.478216

# %%
# current time and date alag alag
print(d.datetime.now().time())
print(d.datetime.now().date())
# Out:
# 11:40:32.999200
# 2026-08-04

# %% [markdown]
# # Time Module

# %%
import time

# %%
# random time chalega
print(time.time())
# Out:
# 1785823891.5717392

# %%
# sleep
print(time.sleep(5))
# Out:
# None
