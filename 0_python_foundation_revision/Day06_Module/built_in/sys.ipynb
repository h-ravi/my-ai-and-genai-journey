# %%
import sys

# %%
print(sys.version)
# Out:
# 3.14.6 (main, Jun 15 2026, 11:36:54) [GCC 16.1.1 20260430]

# %%
print(sys.argv)
# Out:
# ['/home/h/Downloads/Dev/python_projects/pyide/ami/cli.py']

# %%
sys.exit()

# %%
print(__name__)
# Out:
# __main__
