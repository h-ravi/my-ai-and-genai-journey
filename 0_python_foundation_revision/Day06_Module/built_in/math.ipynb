# %%
import math

# %%
# square root
print(math.sqrt(25))
# Out:
# 5.0

# %%
# power like 2 to the power 3 = 8
print(math.pow(2,3))
# Out:
# 8.0

# %%
# factorial
print(math.factorial(5))
# Out:
# 120

# %%
# upper round
print(math.ceil(4.1))
# Out:
# 5

# %%
# lower round
print(math.floor(4.9))
# Out:
# 4

# %%
# deault value
pi = pi value
e =
